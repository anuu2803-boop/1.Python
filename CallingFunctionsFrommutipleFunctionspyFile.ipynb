# %%
from multipleFunctions import mutipleFunctionsClass

# %%
mutipleFunctionsClass.SubFields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
mutipleFunctionsClass.OddEven()
# Out:
# Enter a number:  34
# 34 is Even number

# %%
mutipleFunctionsClass.Elegible()
# Out:
# Your Gender: Male
# Your Age: 34
# ELIGIBLE

# %%
mutipleFunctionsClass.percentage()
# Out:
# Subject1=  90
# Subject2=  98
# Subject3=  90
# Subject4=  98
# Subject5=  87
# Total :  463
# Percentage :  92.60000000000001

# %%
mutipleFunctionsClass.triangle()
# Out:
# Height: 32
# Breadth: 33
# Area formula: (Height*Breadth)/2
# Area of Triangle:  528.0
# Height1: 43
# Height2: 43
# Breadth: 44
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  130
