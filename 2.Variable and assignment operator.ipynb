# %%
num1=10
num2=20
add=num1+num2
print(add)
# Out:
# 30

# %%
print("Addition Of Two Numbers")
# Out:
# Addition Of Two Numbers

# %%
Num1=10
print("The number1 is :",Num1)
# Out:
# The number1 is : 10

# %%
Num2=20
print("The number2 is :",Num2)
# Out:
# The number2 is : 20

# %%
Add = Num1+Num2
print("The result is :",Add)
# Out:
# The result is : 30

# %%
num1=10
num2=20
add=num1+num2
print("Addition Of Two Numbers")
print("The number1 is :",Num1)
print("The number2 is :",Num2)
print("The result is :",Add)
# Out:
# Addition Of Two Numbers
# The number1 is : 10
# The number2 is : 20
# The result is : 30

# %%
Num1 = int(input("The Number 1 is :"))
Num2 = int(input("The Number 2 is :"))
Add = Num1 + Num2
print("The result is :",Add)
# Out:
# The Number 1 is : 10
# The Number 2 is : 20
# The result is : 30
