# %%
lists = [10,20,30,40,50]
for age in lists:
    if (age<20):
        print("Child")
    elif (age>20):
        print("Teenage")
    else:
        print("Man")
# Out:
# Child
# Man
# Teenage
# Teenage
# Teenage
