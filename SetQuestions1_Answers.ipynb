# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible to vote.")
else:
    print("Not eligible to vote.")
# Out:
# Enter your age:  19
# Eligible to vote.

# %%
numbers = [12, 45, 7, 89, 23, 56]
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num
print("The largest number is:", largest)
# Out:
# The largest number is: 89

# %%
salary = float(input("Enter your salary: "))
if salary > 50000:
    bonus = salary * 0.10
else:
    bonus = 0
print("Your bonus is:", bonus)
# Out:
# Enter your salary:  50002
# Your bonus is: 5000.200000000001

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("Even.")
else:
    print("Odd.")
# Out:
# Enter a number:  3
# Odd.

# %%
text = input("Enter a word or sentence: ")
char_list = list(text)
char_list.reverse()
reversed_text = ''.join(char_list)
print("Reversed text:", reversed_text)
# Out:
# Enter a word or sentence:  hopeai
# Reversed text: iaepoh

# %%
marks = int(input("Enter your marks: "))
if marks >= 40:
    print("Pass.")
else:
    print("Fail.")
# Out:
# Enter your marks:  56
# Pass.

# %%
order_amount = float(input("Enter the total order amount: "))
if order_amount > 100:
    discount = order_amount * 0.20
else:
    discount = 0

final_amount = order_amount - discount
print("Final amount to be paid:", final_amount)
# Out:
# Enter the total order amount:  101
# Final amount to be paid: 80.8

# %%
balance = float(input("Enter your account balance: "))
withdrawal = float(input("Enter withdrawal amount: "))
if withdrawal <= balance:
    balance -= withdrawal
    print("Withdrawal successful.")
    print("Updated balance:", balance)
else:
    print("Insufficient funds.")
# Out:
# Enter your account balance:  500000
# Enter withdrawal amount:  500001
# Insufficient funds.

# %%
year = int(input("Enter a year: "))
if year % 400 == 0:
    print("Leap year.")
elif year % 100 == 0:
    print("Not a leap year.")
elif year % 4 == 0:
    print("Leap year.")
else:
    print("Not a leap year.")
# Out:
# Enter a year:  2000
# Leap year.

# %%
numbers = [12, 7, 9, 24, 36, 41, 50]
even_numbers = []
for num in numbers:
    if num % 2 == 0:
        even_numbers.append(num)
print("Even numbers:", even_numbers)
# Out:
# Even numbers: [12, 24, 36, 50]
